# %%
import numpy as np 
import pandas as pd

# %%
age = pd.Series(np.random.randint(20, 50, 30))

# %%
age.head()
# Out:
# 0    26
# 1    44
# 2    43
# 3    22
# 4    24
# dtype: int32

# %%
age.tail()
# Out:
# 25    28
# 26    21
# 27    25
# 28    22
# 29    25
# dtype: int32

# %%
age
# Out:
# 0     26
# 1     44
# 2     43
# 3     22
# 4     24
# 5     28
# 6     49
# 7     39
# 8     35
# 9     25
# 10    47
# 11    45
# 12    45
# 13    37
# 14    28
# 15    37
# 16    44
# 17    20
# 18    27
# 19    36
# 20    30
# 21    26
# 22    21
# 23    24
# 24    26
# 25    28
# 26    21
# 27    25
# 28    22
# 29    25
# dtype: int32

# %%
d = {
    'Country' : ['India', 'China', 'USA', 'Germany'], 
    'Capital' : ['Delhi', 'Beijing', 'Washington D.C.', 'Berlin'], 
    'Currency' : ['INR', 'YUAN', 'USD', 'EUR'], 
    'Development_Status' : ['Developing', 'Developed', 'Developed', 'Developed']
}

# %%
df = pd.DataFrame(d)

# %%
df.head()
# Out:
#    Country          Capital Currency Development_Status
# 0    India            Delhi      INR         Developing
# 1    China          Beijing     YUAN          Developed
# 2      USA  Washington D.C.      USD          Developed
# 3  Germany           Berlin      EUR          Developed

# %%
df.head()
# Out:
#    Country          Capital Currency Development_Status
# 0    India            Delhi      INR         Developing
# 1    China          Beijing     YUAN          Developed
# 2      USA  Washington D.C.      USD          Developed
# 3  Germany           Berlin      EUR          Developed

# %%
new_dict = {'Country' : 'Russia', 'Capital' : 'Moscow', 'Currency' : 'Rubl', 'Development_Status' : "Developed"}

# %%
df2 = pd.DataFrame([new_dict])

# %%
df2.head()
# Out:
#   Country Capital Currency Development_Status
# 0  Russia  Moscow     Rubl          Developed

# %%
df = pd.concat([df, df2], ignore_index=True)

# %%
df.head()
# Out:
#    Country          Capital Currency Development_Status
# 0    India            Delhi      INR         Developing
# 1    China          Beijing     YUAN          Developed
# 2      USA  Washington D.C.      USD          Developed
# 3  Germany           Berlin      EUR          Developed
# 4   Russia           Moscow     Rubl          Developed

# %%
# df[~(df['Country'] == 'China')].reset_index(drop = True)

# %%
df = pd.read_csv("C:\\Users\\Admin\\Desktop\\Python\\dataset.csv")

# %%
df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
df.tail(8)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 760                     0.766   22        0
# 761                     0.403   43        1
# 762                     0.142   33        0
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# ...

# %%
df.sample(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 24            11      143             94             33      146  36.6
# 155            7      152             88             44        0  50.0
# 304            3      150             76              0        0  21.0
# 535            4      132              0              0        0  32.9
# 174            2       75             64             24       55  29.7
# 112            1       89             76             34       37  31.2
# 592            3      132             80              0        0  34.4
# 402            5      136             84             41       88  35.0
# 99             1      122             90             51      220  49.7
# 248            9      124             70             33      402  35.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 24                      0.254   51        1
# 155                     0.337   36        1
# 304                     0.207   37        0
# ...

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df[df['Outcome'] == 1]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df[(df['Pregnancies'] == 0) & (df['Outcome'] == 1)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 4              0      137             40             35      168  43.1
# 16             0      118             84             47      230  45.8
# 45             0      180             66             39        0  42.0
# 66             0      109             88             30        0  32.5
# 78             0      131              0              0        0  43.2
# 109            0       95             85             25       36  37.4
# 120            0      162             76             56      100  53.2
# 124            0      113             76              0        0  33.3
# 129            0      105             84              0        0  27.9
# 164            0      131             88              0        0  31.6
# 177            0      129            110             46      130  67.1
# 213            0      140             65             26      130  42.6
# ...

# %%
# Column Subsetting 

df[['BloodPressure',  'BMI', 'Age']]
# Out:
#      BloodPressure   BMI  Age
# 0               72  33.6   50
# 1               66  26.6   31
# 2               64  23.3   32
# 3               66  28.1   21
# 4               40  43.1   33
# ..             ...   ...  ...
# 763             76  32.9   63
# 764             70  36.8   27
# 765             72  26.2   30
# 766             60  30.1   47
# 767             70  30.4   23
#
# [768 rows x 3 columns]

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.loc[0:4, 'Pregnancies' : 'Insulin']
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin
# 0            6      148             72             35        0
# 1            1       85             66             29        0
# 2            8      183             64              0        0
# 3            1       89             66             23       94
# 4            0      137             40             35      168

# %%
df.iloc[0:4, 0:4]
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness
# 0            6      148             72             35
# 1            1       85             66             29
# 2            8      183             64              0
# 3            1       89             66             23

# %%
# Summerizing the data 

print(f"Shape of DataFrame : {df.shape}")
# Out:
# Shape of DataFrame : (768, 9)

# %%
df['Pregnancies'].unique()
# Out:
# array([ 6,  1,  8,  0,  5,  3, 10,  2,  4,  7,  9, 11, 13, 15, 17, 12, 14])

# %%
df['Pregnancies'].nunique()
# Out:
# 17

# %%
df['Pregnancies'].value_counts()
# Out:
# Pregnancies
# 1     135
# 0     111
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 13     10
# 12      9
# 14      2
# 17      1
# 15      1
# Name: count, dtype: int64

# %%
# min, max, sum, count, mean, std, var

print(df['BloodPressure'].min())
print(df['BloodPressure'].max()) 
print(df['BloodPressure'].mean()) 
print(df['BloodPressure'].std()) 
print(df['BloodPressure'].var()) 
print(df['BloodPressure'].count()) 
print(df['BloodPressure'].sum())
# Out:
# 0
# 122
# 69.10546875
# 19.355807170644777
# 374.6472712271838
# 768
# 53073

# %%
df['BloodPressure'].describe()
# Out:
# count    768.000000
# mean      69.105469
# std       19.355807
# min        0.000000
# 25%       62.000000
# 50%       72.000000
# 75%       80.000000
# max      122.000000
# Name: BloodPressure, dtype: float64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...
